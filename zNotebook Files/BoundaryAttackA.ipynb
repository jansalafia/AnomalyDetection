# %% [markdown]
# # BoundaryAttack on scikit-learn models — Scaled to [0,1] (Option A)
#
# Notebook scales features to [0,1], trains models, runs untargeted BoundaryAttack, saves adversarial examples (including adversarial feature vectors), and creates quick visualizations.
#
# Edit DATA_PATH at the top to point to your CSV if needed. The notebook expects a label column named `anomaly` or the last column will be treated as the label.

# %%
# Install if necessary (uncomment)
# !pip install adversarial-robustness-toolbox scikit-learn xgboost pandas numpy matplotlib

# %%
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, classification_report

from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

try:
    from xgboost import XGBClassifier
    has_xgb = True
except Exception:
    XGBClassifier = None
    has_xgb = False

from art.attacks.evasion import BoundaryAttack
from art.estimators.classification import SklearnClassifier

print('xgboost available:', has_xgb)
# Out:
# xgboost available: True

# %%
# === Configuration: change DATA_PATH string if needed ===
DATA_PATH = 'C:/Users/Jan/Git/AnomalyDetection/CSVs/newDataset.csv'   # <-- change to your CSV path (string)
LABEL_COL = 'anomaly'                    # or set to your label column name
TEST_SIZE = 0.8
RANDOM_STATE = 100

# Scaling to [0,1] (Option A)
CLIP_VALUES = (0.0, 1.0)

# Recommended BoundaryAttack params for scaled data (Option A)
N_ATTACK = 2122  # number of samples to attack
BOUNDARY_PARAMS = dict(
    max_iter = 200,
    delta    = 0.01,
    epsilon  = 1e-6,
    targeted = False
)

OUT_DIR = Path('Results/BoundaryAttack_optionA')
OUT_DIR.mkdir(parents=True, exist_ok=True)

# %%
# --- Load data ---
DATA_PATH_OBJ = Path(DATA_PATH)
assert DATA_PATH_OBJ.exists(), f"CSV not found: {DATA_PATH}"
df = pd.read_csv(DATA_PATH_OBJ)

if LABEL_COL not in df.columns:
    print(f"Warning: label column '{LABEL_COL}' not found. Using last column as label instead.")
    LABEL_COL = df.columns[-1]

y = df[LABEL_COL].astype(int).values
feature_cols = [c for c in df.columns if c != LABEL_COL]
X = df[feature_cols].values

print('Loaded:', DATA_PATH_OBJ, 'samples=', X.shape[0], 'features=', X.shape[1])
# Out:
# Loaded: C:\Users\Jan\Git\AnomalyDetection\CSVs\newDataset.csv samples= 2123 features= 22

# %%
# --- Train/Test split & scaling to [0,1] ---
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE,
                                                    stratify=y, random_state=RANDOM_STATE)

scaler = MinMaxScaler(feature_range=CLIP_VALUES)
X_train_sc = scaler.fit_transform(X_train)
X_test_sc  = scaler.transform(X_test)

print('Shapes:', X_train_sc.shape, X_test_sc.shape)
# Out:
# Shapes: (424, 22) (1699, 22)

# %%
# --- Train sklearn models (simple defaults) ---
models = {}
lr = LogisticRegression(max_iter=1000, class_weight='balanced', random_state=RANDOM_STATE)
lr.fit(X_train_sc, y_train); models['LogisticRegression'] = lr

mlp = MLPClassifier(hidden_layer_sizes=(128,64), max_iter=300, random_state=RANDOM_STATE)
mlp.fit(X_train_sc, y_train); models['MLPClassifier'] = mlp

svm = SVC(probability=True, kernel='rbf', random_state=RANDOM_STATE)
svm.fit(X_train_sc, y_train); models['SVM'] = svm

rf = RandomForestClassifier(n_estimators=200, random_state=RANDOM_STATE)
rf.fit(X_train_sc, y_train); models['RandomForest'] = rf

if has_xgb:
    xgb = XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=RANDOM_STATE)
    xgb.fit(X_train_sc, y_train); models['XGBClassifier'] = xgb
else:
    print('XGBoost not available; skipped.')

for name, m in models.items():
    print(f"{name}: test acc =", accuracy_score(y_test, m.predict(X_test_sc)))
# Out:
# LogisticRegression: test acc = 0.8987639788110653
# MLPClassifier: test acc = 0.9446733372572101
# SVM: test acc = 0.8917010005885815
# RandomForest: test acc = 0.9440847557386698
# XGBClassifier: test acc = 0.9440847557386698

# %%
# --- Wrap with ART SklearnClassifier ---
art_classifiers = {}
for name, m in models.items():
    try:
        clf = SklearnClassifier(model=m, clip_values=CLIP_VALUES)
        art_classifiers[name] = clf
    except Exception as e:
        print(f"Could not wrap {name}: {e}")
# Out:
# Could not wrap XGBClassifier: Model is not an sklearn model. Received '<class 'xgboost.sklearn.XGBClassifier'>'

# %%
# Helper: convert ART/sklearn predict outputs to 1D labels
def art_probs_to_labels(probs):
    probs = np.asarray(probs)
    if probs.ndim == 1:
        return (probs >= 0.5).astype(int)
    if probs.ndim == 2:
        if probs.shape[1] == 1:
            return (probs.ravel() >= 0.5).astype(int)
        return np.argmax(probs, axis=1).astype(int)
    raise ValueError(f"Unexpected prediction shape: {probs.shape}")

# %%
# --- Run untargeted BoundaryAttack on a subset and save adversarial examples ---
from sklearn.metrics import accuracy_score
n_attack = min(N_ATTACK, X_test_sc.shape[0])
X_eval = X_test_sc[:n_attack]
y_eval = y_test[:n_attack].astype(int)

results = {}
for name, clf in art_classifiers.items():
    print('\n' + '='*60)
    print('Attacking model:', name)
    try:
        attack = BoundaryAttack(estimator=clf, **BOUNDARY_PARAMS)
        # untargeted: don't pass y (passing y may be interpreted as targets)
        X_adv = attack.generate(x=X_eval)
        # Convert predictions to labels
        y_pred_clean = art_probs_to_labels(clf.predict(X_eval))
        y_pred_adv   = art_probs_to_labels(clf.predict(X_adv))

        acc_clean = accuracy_score(y_eval, y_pred_clean)
        acc_adv   = accuracy_score(y_eval, y_pred_adv)
        print(f"Clean acc: {acc_clean:.4f} | Adv acc: {acc_adv:.4f}")
        results[name] = dict(clean_acc=acc_clean, adv_acc=acc_adv)

        # Save adversarial examples with both clean and adv features (inverse scaled to original)
        X_clean_inv = scaler.inverse_transform(X_eval)
        X_adv_inv   = scaler.inverse_transform(X_adv)

        df_out = pd.DataFrame(X_clean_inv, columns=feature_cols)
        # prefix adv features with adv_
        adv_cols = [f"adv_{c}" for c in feature_cols]
        df_adv = pd.DataFrame(X_adv_inv, columns=adv_cols)
        df_save = pd.concat([df_out.reset_index(drop=True), df_adv.reset_index(drop=True)], axis=1)
        df_save['label_true'] = y_eval
        df_save['pred_clean'] = y_pred_clean
        df_save['pred_adv'] = y_pred_adv

        save_path = OUT_DIR / f"{name}_adv_examples.csv"
        df_save.to_csv(save_path, index=False)
        print('Saved adversarial examples to:', save_path)
    except Exception as e:
        print('Attack failed for', name, ':', e)
# Out:
# ============================================================
# Attacking model: LogisticRegression
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1351.20it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1549.67it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1326.64it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1470.30it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1433.55it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1390.42it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1506.87it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1508.43it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1491.29it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1428.97it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1443.60it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1457.03it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1345.38it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1561.98it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1486.57it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1325.49it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1520.76it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1350.69it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1486.70it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1422.94it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1479.58it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1470.13it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1315.54it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1602.25it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1576.79it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1492.00it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1486.09it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1438.33it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1365.05it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1497.70it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1428.07it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1423.19it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1526.39it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1355.54it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1408.16it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1454.01it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1454.20it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1484.54it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1383.75it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1427.98it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1580.49it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1525.95it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1525.73it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 1423.01it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:00<00:00, 
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 85.59it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 95.33it/s]
# Boundary attack - iterations:  12%|█▏        | 23/200 [00:00<00:02, 76.61it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 82.52it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 89.36it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 90.12it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 90.69it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 93.47it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 91.25it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 92.61it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 86.18it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 91.64it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 91.24it/s]
# Boundary attack - iterations:  17%|█▋        | 34/200 [00:00<00:02, 76.62it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 86.36it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 92.72it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 92.03it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 92.12it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 94.64it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 90.89it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 87.79it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 92.07it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 92.13it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 90.93it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 89.04it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 93.73it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 95.57it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 94.47it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 94.86it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 94.46it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 94.59it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 89.55it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 93.11it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 89.27it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 84.73it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 93.72it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 89.95it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 83.85it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 91.41it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 91.85it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 93.64it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 87.33it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 90.04it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 96.32it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 95.55it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 96.36it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 93.31it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 98.22it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 99.52it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 98.93it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 80.93it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 89.04it/s]
# Boundary attack - iterations:  14%|█▍        | 28/200 [00:00<00:02, 73.31it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 89.24it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 92.77it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 92.90it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 92.15it/s]
# Boundary attack - iterations:  16%|█▌        | 31/200 [00:00<00:02, 74.13it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 86.36it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:01<00:00, 101.20it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 88.59it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 85.07it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:01<00:00, 100.15it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 94.07it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 84.15it/s]
# Boundary attack - iterations:  11%|█         | 22/200 [00:00<00:02, 71.02it/s]
# Boundary attack - iterations:  13%|█▎        | 26/200 [00:00<00:02, 76.75it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 89.95it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 81.00it/s]
# Boundary attack - iterations:  10%|█         | 21/200 [00:00<00:02, 69.80it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 91.46it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 87.25it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 79.97it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 87.32it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 91.72it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 89.78it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 90.87it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 89.95it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 90.96it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 89.69it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 93.04it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 88.95it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 92.65it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 90.29it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 93.91it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 93.68it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 90.21it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 92.74it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 91.96it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 92.93it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 86.91it/s]
# Boundary attack - iterations:  10%|█         | 21/200 [00:00<00:02, 72.46it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 88.97it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 90.88it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 88.31it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 92.07it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 91.00it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 92.40it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 94.78it/s]
# Boundary attack - iterations:  10%|█         | 21/200 [00:00<00:02, 72.54it/s]
# Boundary attack - iterations:  16%|█▌        | 32/200 [00:00<00:02, 74.79it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 93.64it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 89.49it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 87.92it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 95.45it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 96.65it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 91.22it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 86.46it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 91.31it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 95.25it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 87.41it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 82.65it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 76.00it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 79.62it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 84.79it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 74.80it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 78.25it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 86.16it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 89.77it/s]
# Boundary attack - iterations:  14%|█▎        | 27/200 [00:00<00:02, 72.55it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 84.18it/s]
# Boundary attack - iterations:  17%|█▋        | 34/200 [00:00<00:02, 79.02it/s]
# Boundary attack - iterations:  14%|█▍        | 29/200 [00:00<00:02, 79.49it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 87.16it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 86.54it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 87.42it/s]
# Boundary attack - iterations:  14%|█▍        | 28/200 [00:00<00:02, 67.67it/s]
# Boundary attack - iterations:  12%|█▏        | 23/200 [00:00<00:02, 74.26it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 84.99it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 88.06it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 85.91it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 88.07it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 92.60it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 93.05it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 94.32it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 83.28it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 89.60it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 94.85it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 94.98it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 92.44it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 91.61it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 93.04it/s]
# Boundary attack - iterations:  18%|█▊        | 35/200 [00:00<00:02, 76.60it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 92.33it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 92.83it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 93.62it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 90.52it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 95.42it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 91.98it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 97.21it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 92.34it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 91.26it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 94.00it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 92.73it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 89.33it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 91.94it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 87.19it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 91.71it/s]
# Boundary attack - iterations:  20%|██        | 40/200 [00:00<00:01, 83.86it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 92.43it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 89.48it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 90.25it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 91.95it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 88.03it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 84.72it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 89.56it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 91.45it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 86.74it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 88.30it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 88.52it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 93.87it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 94.66it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 91.81it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 83.94it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 89.55it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 89.09it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 88.01it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 83.37it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 76.63it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 80.04it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 83.30it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 81.04it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 88.44it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 85.34it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 86.80it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 88.96it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 89.69it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 85.67it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 96.97it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 91.13it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 91.40it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 91.87it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 84.82it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 90.99it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 89.82it/s]
# Boundary attack - iterations: 100%|██████████| 200/200 [00:02<00:00, 90.57it/s]
# Boundary attack: 100%|██████████| 1699/1699 [50:33<00:00,  1.79s/it]
# Clean acc: 0.9441 | Adv acc: 0.2048
# Saved adversarial examples to: Results\BoundaryAttack_optionA\RandomForest_adv_examples_optionA.csv

# %% [markdown]
# ## Quick visualizations
# The next cell will load the saved CSVs and produce a summary table plus a bar chart of clean vs adversarial accuracy.

# %%
# --- Visualize results from saved CSVs ---
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.metrics import accuracy_score

OUT_DIR = Path('Results/BoundaryAttack_optionA')  # <-- correct folder for Option A
files = list(OUT_DIR.glob('*_adv_examples_optionA.csv'))
if not files:
    raise FileNotFoundError(f'No CSVs found in {OUT_DIR}. '
                            f'Expected files like <Model>_adv_examples_optionA.csv')

summaries = []
per_model_frames = {}
for csv in files:
    name = csv.stem.replace('_adv_examples_optionA','')
    df = pd.read_csv(csv)
    per_model_frames[name] = df
    acc_clean = accuracy_score(df['label_true'], df['pred_clean'])
    acc_adv   = accuracy_score(df['label_true'], df['pred_adv'])
    flip_rate = (df['pred_clean'] != df['pred_adv']).mean()
    summaries.append({'model': name, 'clean_acc': acc_clean, 'adv_acc': acc_adv, 'flip_rate': flip_rate})

summary_df = pd.DataFrame(summaries)
if summary_df.empty:
    raise RuntimeError('Summary DataFrame is empty — no results aggregated.')
summary_df = summary_df.sort_values('adv_acc', ascending=False).reset_index(drop=True)
display(summary_df)

# Bar chart
labels = summary_df['model'].tolist()
clean  = summary_df['clean_acc'].values
adv    = summary_df['adv_acc'].values

plt.figure(figsize=(8,4))
x = np.arange(len(labels))
w = 0.35
plt.bar(x - w/2, clean, width=w, label='Clean')
plt.bar(x + w/2, adv,   width=w, label='Adversarial')
plt.xticks(x, labels, rotation=20, ha='right')
plt.ylabel('Accuracy')
plt.title('Clean vs Adversarial Accuracy by Model')
plt.legend()
plt.tight_layout()
plt.show()

# Using sklearn's ConfusionMatrixDisplay with side-by-side comparisons
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

for name, df in per_model_frames.items():
    y_true = df['label_true'].to_numpy()
    
    # Create a figure with two subplots side by side
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
    
    # Plot clean predictions
    cm_clean = confusion_matrix(y_true, df['pred_clean'])
    disp_clean = ConfusionMatrixDisplay(cm_clean)
    disp_clean.plot(ax=ax1)
    ax1.set_title(f'{name} — Clean Predictions')
    
    # Plot adversarial predictions
    cm_adv = confusion_matrix(y_true, df['pred_adv'])
    disp_adv = ConfusionMatrixDisplay(cm_adv)
    disp_adv.plot(ax=ax2)
    ax2.set_title(f'{name} — Adversarial Predictions')
    
    plt.suptitle(f'Confusion Matrices for {name}', y=1.05)
    plt.tight_layout()
    plt.show()
# Out:
#                 model  clean_acc   adv_acc  flip_rate
# 0        RandomForest   0.944085  0.204826   0.826368
# 1                 SVC   0.921719  0.200118   0.831077
# 2       MLPClassifier   0.944673  0.190700   0.811654
# 3  LogisticRegression   0.898764  0.104179   0.989994
